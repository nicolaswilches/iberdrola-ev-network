# %% [markdown]
# # 07 — Network Optimization
#
# Run the station placement optimization. Inputs: road network with demand, existing charger locations, spacing constraints. Output: list of proposed new station locations with `n_chargers_proposed`.
#
# Algorithm: minimize total stations while ensuring full coverage (no gap > `MAX_STATION_SPACING_KM`).

# %% [markdown]
# ## Data Inputs
# - `data/processed/interurban_roads.geojson`
# - `data/processed/interurban_chargers.csv`
# - `data/processed/demand_per_segment.csv`
# - `data/raw/additional/osm_rest_areas/` — candidate locations
# - `data/raw/additional/tent_corridors/` — AFIR compliance check
#
# ## Data Outputs
# - `data/processed/proposed_stations.csv`
#   Columns: location_id, latitude, longitude, route_segment, n_chargers_proposed

# %%
# TODO: implement
import pandas as pd
import geopandas as gpd
import numpy as np
from src.constants import MAX_STATION_SPACING_KM, AFIR_SPACING_KM

print('Running network optimization...')
