# %% [markdown]
# # 06 — Demand Modeling
#
# Combine: road network segments + DGT traffic counts (IMD) + EV fleet projection 2027 + seasonal multipliers. Calculate projected daily EV traffic per road segment. Determine required number of chargers per station candidate.

# %% [markdown]
# ## Data Inputs
# - `data/processed/interurban_roads.geojson`
# - `data/processed/road_segments_with_imd.csv`
# - `data/processed/ev_projection_2027.csv`
# - `data/raw/additional/ine_population/`
#
# ## Data Outputs
# - `data/processed/demand_per_segment.csv`
#   Columns: segment_id, route_segment, daily_ev_traffic_2027, n_chargers_needed, is_coastal, seasonal_multiplier

# %%
# TODO: implement
import pandas as pd
import numpy as np
from src.constants import CHARGING_PROBABILITY, AVG_CHARGE_DURATION_HOURS, EFFECTIVE_OPERATING_HOURS

print('Building demand model...')
